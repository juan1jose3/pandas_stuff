# %% [markdown]
# <center><font color='steelblue'> <font size = "5,5">CORPORACIÓN UNIVERSITARIA MINUTO DE DIOS </font></center><br>
# <center><font color='steelblue'> <font size = "5">FACULTAD DE INGENIERÍA</font></center><br>
# <center><font color='steelblue'> <font size = "4">PROGRAMA INGENIERÍA DE SISTEMAS</font></center><br>
# <center><font color='steelblue'> <font size = "3">CURSO BASES DE DATOS MASIVAS</font></center><br>
# <center><font color="yellow" size = "4" face = "small fonts">Talle PYTHON</font></center>

# %% [markdown]
# <center><font color="olive" size = "4" face = "small fonts">DATOS DE LOS PARTICIPANTES DEL GRUPO</font></center>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">NRC: 83355</font></center><br>
# <font color="yellow" size = "4" face = "small fonts">Nombre: Juan Jose Morales Benitez / David Vargas </font></center><br>
# <font color="yellow" size = "4" face = "small fonts">ID: 879302 / ID:824144 </font></center><br>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">El taller retoma algunas de las instrucciones utilizadas a través del curso de Bases de Datos Masivas, tener en cuenta seguir los pasos requeridos.</font></center><br>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">Al Cargar los archivos dispuestos en la carpeta TERCERPARCIAL se debe utilizar sentencias que no fijen el path, este debe se dinámico en caso de que se creen nuevos paquetes</font></center><br>
# .

# %% [markdown]
# <font color="red" size = "4" face = "small fonts">El ejercicio consta de seguir el cuaderno y  realizar las tareas solicitadas, Utilizar y citar la documentación propia de cada una de las herramientas utilizadas para realizar el tratamiento a la data.</font></center><br>

# %% [markdown]
# <font color="red" size = "4" face = "small fonts">Calificación del siguiente bloque 1/5</font></center><br>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">1. Configuración e importe de las librerias de pandas y propias.</font></center><br>

# %%
#Utilizar las buenas practicas de python

import os
import sys
import io
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath(os.path.join('..')))
from functions.misfunciones import unir_excel_en_csv,alterar_columnas,establecer_conexion,cargar_datos,cantidad_por_producto,obtener_datos_tiempo,crear_nueva_db,perform_basic_select

PARCIALDB ="parcialDB"
BDRH = "bdrh"

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">2. Leer un archivo.CSV e imprimirlo desde la carpeta data</font></center><br>

# %%
#Utilizar las buenas practicas de python
csv_path = os.path.join(os.getcwd(), ".." , "data" , "data.csv")

file = pd.read_csv(csv_path, encoding='latin1',low_memory=False)
file.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">3. Leer un archivo.HTML que contenga data e imprimirlo desde un sitio WEB</font></center><br>

# %%
#Utilizar las buenas practicas de python

headers = {"User-Agent":"Mozilla/5.0"}
url = "https://en.wikipedia.org/wiki/Demographics_of_Russia"

response = requests.get(url,headers=headers)

russian_population = pd.read_html(io.StringIO(response.text), match="Vital Statistics of Russia as of 1946")[0]

russian_population.head()
# Out:
#   Unnamed: 0_level_0 Total average population (1 January 1993 onwards)  \
#   Unnamed: 0_level_1 Total average population (1 January 1993 onwards)
# 0               1946                                          98028000
# 1               1947                                          98834000
# 2               1948                                          99706000
# 3               1949                                         101160000
# 4               1950                                         102833000
#
#   Live births     Deaths Natural change Crude birth rate (per 1,000)  \
#   Live births     Deaths Natural change Crude birth rate (per 1,000)
# 0     2546000  1210000.0      1336000.0                         26.0
# 1     2715000  1680000.0      1035000.0                         27.5
# 2     2516000  1310000.0      1206000.0                         25.2
# 3     3089000  1187000.0      1902000.0                         30.5
# 4     2859000  1180000.0      1679000.0                         27.8
#
#   Crude death rate (per 1,000) Natural change (per 1,000)  \
#   Crude death rate (per 1,000) Natural change (per 1,000)
# 0                         12.3                       13.6
# 1                         17.0                       10.5
# 2                         13.1                       12.1
# 3                         11.7                       18.8
# 4                         11.5                       16.3
#
#   Crude migration change (per 1,000) Total fertility rate[fn 2] Fertility  \
#   Crude migration change (per 1,000) Total fertility rate[fn 2]     urban
# 0                               -5.4                       2.81       NaN
# 1                               -1.7                       2.94       NaN
# 2                                2.5                       2.60       NaN
# 3                               -2.3                       3.21       NaN
# 4                               -0.7                       2.89       NaN
#
#         Life Expectancy               \
#   rural            male female total
# 0   NaN            46.6   55.3   NaN
# 1   NaN            39.9   49.8   NaN
# 2   NaN            47.0   56.0   NaN
# 3   NaN            51.0   59.8   NaN
# 4   NaN            52.3   61.0   NaN
#
#   Abortions reported (including miscarriages)
#   Abortions reported (including miscarriages)
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">4. Leer un archivo.XLSX que contenga data e imprimirlo desde el modulo /data</font></center><br>

# %%
#Utilizar las buenas practicas de python
excel_path = os.path.join(os.getcwd(),"..","data","RELAX1.XLSX")

excel = pd.read_excel(excel_path)
excel.head(10)
# Out:
#    Mat.gestion.stock     Material            Texto breve de material  TpMt  \
# 0        71000000091  91000000001                WIRE, NONELECTRICAL  HERS
# 1        71000000091  91000000002                WIRE, NONELECTRICAL  HERS
# 2        71000000091  91000000003                WIRE, NONELECTRICAL  HERS
# 3        71000000125  91000000004                WIRE, NONELECTRICAL  HERS
# 4        71000000158  91000252927  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
# 5        71000000182  91000000006  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
# 6        71000000182  91000000007  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
# 7        71000000182  91000000008  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
# 8        71000000182  91000000009  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
# 9        71000000182  91000252928  CABLE ASSEMBLY, POWER, ELECTRICAL  HERS
#
#   UMB  Mat  SM  Grupo art.  Jquía.productos                           NºFb  \
# 0   M  NaN NaN      261215              NaN                       10011477
# 1   M  NaN NaN      261215              NaN                         200303
# 2   M    X NaN      261215              NaN                         200354
# 3   M  NaN NaN      261215              NaN               2051016R - NEGRO
# 4   M  NaN NaN      261216              NaN  C THHN/THWN 90°C CU 2 AWG 600
# 5   M  NaN NaN      261216              NaN                        4 CAUCA
# 6   M  NaN NaN      261216              NaN                 CABLE 4AWG-THW
# 7   M  NaN NaN      261216              NaN                       10011394
# 8   M  NaN NaN      261216              NaN                       2004008S
# 9   M  NaN NaN      261216              NaN  C THHN/THWN 90°C CU 4 AWG 600
#
#   Fabricante  Grupo artíc. ext.     Creado   Últ.mod.
# 0   CENTELSA                NaN 2016-04-27 2022-10-03
# 1   CENTELSA                NaN 2016-04-27 2022-10-03
# 2   CENTELSA                NaN 2016-04-27 2022-10-03
# 3   CENTELSA                NaN 2016-04-27 2022-10-03
# 4   CENTELSA                NaN 2016-04-27 2022-10-03
# 5   CEAT-GEN                NaN 2016-04-27 2022-10-03
# 6   CEAT-GEN                NaN 2016-04-27 2022-10-03
# 7   CENTELSA                NaN 2016-04-27 2022-10-03
# 8   CENTELSA                NaN 2016-04-27 2022-10-03
# 9   CENTELSA                NaN 2016-04-27 2022-10-03

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">5. Leer un archivo.JSON que contenga data e imprimirlo desde el modulo /data</font></center><br>

# %%
#Utilizar las buenas practicas de python
json_path = os.path.join(os.getcwd(),"..", "data", "pokemons.json")


with open(json_path, mode="r") as file:
    data = json.load(file)

json_data = pd.json_normalize(data["results"])
json_data.head(25)
# Out:
#           name                                    url
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/
# 12      weedle  https://pokeapi.co/api/v2/pokemon/13/
# 13      kakuna  https://pokeapi.co/api/v2/pokemon/14/
# 14    beedrill  https://pokeapi.co/api/v2/pokemon/15/
# 15      pidgey  https://pokeapi.co/api/v2/pokemon/16/
# 16   pidgeotto  https://pokeapi.co/api/v2/pokemon/17/
# 17     pidgeot  https://pokeapi.co/api/v2/pokemon/18/
# 18     rattata  https://pokeapi.co/api/v2/pokemon/19/
# 19    raticate  https://pokeapi.co/api/v2/pokemon/20/
# 20     spearow  https://pokeapi.co/api/v2/pokemon/21/
# 21      fearow  https://pokeapi.co/api/v2/pokemon/22/
# 22       ekans  https://pokeapi.co/api/v2/pokemon/23/
# 23       arbok  https://pokeapi.co/api/v2/pokemon/24/
# 24     pikachu  https://pokeapi.co/api/v2/pokemon/25/

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">6. Leer un archivo desde una URL de extensión CSV e imprimirlo</font></center><br>

# %%
#Utilizar las buenas practicas de python
csv_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

web_csv = pd.read_csv(csv_url)
web_csv.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">7. Para almacenar datos manualmente en una tabla, cree un DataFrame. Al utilizar un diccionario Python de listas, las claves del diccionario se utilizarán como cabeceras de columna y los valores de cada lista como columnas del DataFrame.
#
# Un DataFrame es una estructura de datos bidimensional que puede almacenar datos de diferentes tipos (incluyendo caracteres, enteros, valores de coma flotante, datos categóricos y más) en columnas. Es similar a una hoja de cálculo, una tabla SQL o el data.frame en R.
#
# Cree una tabla que tiene 3 columnas, cada una de ellas con una etiqueta. Las etiquetas de las columnas son respectivamente Nombre, Edad y Sexo.
#
# La columna Nombre consiste en datos textuales con cada valor una cadena, la columna Edad son números y la columna Sexo son datos textuales.</font></center><br>

# %%
#Utilizar las buenas practicas de python
people = {
    "Nombre":["Juan","María"],
    "Edad":[21,22],
    "Sexo":["M","F"]      
}

people_data_frame = pd.DataFrame(data=people)
people_data_frame
# Out:
#   Nombre  Edad Sexo
# 0   Juan    21    M
# 1  María    22    F

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">8. Solo interesa trabajar con los datos de la columna Edad, Imprima los datos de esta columna</font></center><br>
# <font color="yellow" size = "4" face = "small fonts"> -  - Imprima los datos de esta columna</font></center><br>

# %%
for i in people_data_frame.values:
    print(i[1])
# Out:
# 21
# 22

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">9. Consulte que otro tipo de archivo se pueden cargar en pandas y carguelo e imprimalo-</font></center><br>

# %%
#Decidí escanear un RSS que usa xml de mi podcast favorito jeje
xml_url = "https://podcasts.files.bbci.co.uk/p02nq0gn.rss"
response = requests.get(xml_url,headers)
xml_data = pd.read_xml(io.StringIO(response.text),xpath=".//item")
xml_data.head(10)
# Out:
#                                                title  \
# 0  Trump considering 'winding down' Iran military...
# 1              Iran renews attacks on Gulf countries
# 2  Israel holds off attacking Iranian gas infrast...
# 3  Oil and gas prices surge after energy plant st...
# 4         Iran attacks energy facilities in the Gulf
# 5  Israel's third top-level assassination in two ...
# 6          Deadly Israeli strikes hit central Beirut
# 7  Israel says it's killed Iran's top security chief
# 8  US allies reject Trump's call for help in Stra...
# 9  Germany and UK tell Trump this is 'not Nato's ...
#
#                                          description  \
# 0  <p>President Trump posted on social media that...
# 1  <p>Tehran has fired missiles and drones at its...
# 2  <p>The Israeli prime minister, Benjamin Netany...
# 3  <p>Energy prices have surged after strikes on ...
# 4  <p>Qatar's state-owned petroleum company says ...
# 5  <p>Iran's Intelligence Minister Esmail Khatib ...
# 6  <p>Israel has launched a series of deadly stri...
# 7  <p>Israel's foreign minister said Iranians wer...
# 8  <p>The US President has repeated his call for ...
# 9  <p>Germany and Britain say the war against Ira...
#
#                                             subtitle  \
# 0  President Trump says the US is getting very cl...
# 1  Tehran continues to fire missiles and drones a...
# 2  President Trump said he wasn't consulted over ...
# 3  Qatar calls attacks on gas facilities 'dangero...
# 4  Trump threatens to "blow up" Iran's main gas f...
# 5  Iran condemns 'cowardly assassination' of its ...
# 6  Lebanon says at least six killed in Israeli at...
# 7  Israel's foreign minister says Iranians are 's...
# 8  Donald Trump is met with resistance after call...
# 9  The US president had called on allies to help ...
#
#                                              summary  image  \
# 0  <p>President Trump posted on social media that...    NaN
# 1  <p>Tehran has fired missiles and drones at its...    NaN
# 2  <p>The Israeli prime minister, Benjamin Netany...    NaN
# 3  <p>Energy prices have surged after strikes on ...    NaN
# 4  <p>Qatar's state-owned petroleum company says ...    NaN
# 5  <p>Iran's Intelligence Minister Esmail Khatib ...    NaN
# 6  <p>Israel has launched a series of deadly stri...    NaN
# 7  <p>Israel's foreign minister said Iranians wer...    NaN
# 8  <p>The US President has repeated his call for ...    NaN
# 9  <p>Germany and Britain say the war against Ira...    NaN
#
#                            pubDate  duration  enclosure  enclosureLegacy  \
# 0  Sat, 21 Mar 2026 04:45:00 +0000      1813        NaN              NaN
# 1  Fri, 20 Mar 2026 16:36:00 +0000      1986        NaN              NaN
# 2  Fri, 20 Mar 2026 05:26:00 +0000      1465        NaN              NaN
# 3  Thu, 19 Mar 2026 17:03:00 +0000      1709        NaN              NaN
# 4  Thu, 19 Mar 2026 05:34:00 +0000      1641        NaN              NaN
# 5  Wed, 18 Mar 2026 16:28:00 +0000      1685        NaN              NaN
# 6  Wed, 18 Mar 2026 05:28:00 +0000      1690        NaN              NaN
# 7  Tue, 17 Mar 2026 16:59:00 +0000      1671        NaN              NaN
# 8  Tue, 17 Mar 2026 05:38:00 +0000      1738        NaN              NaN
# 9  Mon, 16 Mar 2026 16:28:00 +0000      1736        NaN              NaN
#
#    enclosureSecure                      guid  \
# 0              NaN  urn:bbc:podcast:p0n7z41l
# 1              NaN  urn:bbc:podcast:p0n7wqg4
# 2              NaN  urn:bbc:podcast:p0n7rdv4
# 3              NaN  urn:bbc:podcast:p0n7nk1r
# 4              NaN  urn:bbc:podcast:p0n7gwsq
# 5              NaN  urn:bbc:podcast:p0n7cx19
# 6              NaN  urn:bbc:podcast:p0n77nj0
# 7              NaN  urn:bbc:podcast:p0n75gry
# 8              NaN  urn:bbc:podcast:p0n71mlm
# 9              NaN  urn:bbc:podcast:p0n6zd4b
#
#                                        link explicit  content  \
# 0  http://www.bbc.co.uk/programmes/p0n7z41l    clean      NaN
# 1  http://www.bbc.co.uk/programmes/p0n7wqg4    clean      NaN
# 2  http://www.bbc.co.uk/programmes/p0n7rdv4    clean      NaN
# 3  http://www.bbc.co.uk/programmes/p0n7nk1r    clean      NaN
# 4  http://www.bbc.co.uk/programmes/p0n7gwsq    clean      NaN
# 5  http://www.bbc.co.uk/programmes/p0n7cx19    clean      NaN
# 6  http://www.bbc.co.uk/programmes/p0n77nj0    clean      NaN
# 7  http://www.bbc.co.uk/programmes/p0n75gry    clean      NaN
# 8  http://www.bbc.co.uk/programmes/p0n71mlm    clean      NaN
# 9  http://www.bbc.co.uk/programmes/p0n6zd4b    clean      NaN
#
#               author             canonical
# 0  BBC World Service  /programmes/p0n7z41l
# 1  BBC World Service  /programmes/p0n7wqg4
# 2  BBC World Service  /programmes/p0n7rdv4
# 3  BBC World Service  /programmes/p0n7nk1r
# 4  BBC World Service  /programmes/p0n7gwsq
# 5  BBC World Service  /programmes/p0n7cx19
# 6  BBC World Service  /programmes/p0n77nj0
# 7  BBC World Service  /programmes/p0n75gry
# 8  BBC World Service  /programmes/p0n71mlm
# 9  BBC World Service  /programmes/p0n6zd4b

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">10. Consulte que otro tipo de archivo se pueden cargar en pandas y carguelo e imprimalo-</font></center><br>

# %%
# leer tablas cuando se copia o pega la tabla, jajaja me funcionó con la tabla en está pagina, copia y pega la tabla y corre esto https://en.wikipedia.org/wiki/Demographics_of_Germany

clip_board = pd.read_clipboard()
clip_board.head(20)
# Out:
#    Age group        Male      Female       Total Percent
# 0      Total  39,145,941  41,073,754  80,219,695     100
# 1        0–4   1,714,872   1,624,023   3,338,895    4.16
# 2        5–9   1,809,024   1,716,806   3,525,830    4.40
# 3      10–14   2,021,305   1,919,261   3,940,566    4.91
# 4      15–19   2,057,155   1,956,725   4,013,880    5.00
# 5      20–24   2,463,932   2,371,707   4,835,639    6.03
# 6      25–29   2,455,885   2,416,648   4,872,533    6.07
# 7      30–34   2,385,305   2,366,606   4,751,911    5.92
# 8      35–39   2,378,055   2,364,838   4,742,893    5.91
# 9      40–44   3,209,481   3,141,708   6,351,189    7.92
# 10     45–49   3,547,254   3,452,425   6,999,679    8.73
# 11     50–54   3,113,463   3,092,831   6,206,294    7.74
# 12     55–59   2,668,976   2,750,474   5,419,450    6.76
# 13     60–64   2,298,903   2,403,912   4,702,815    5.86
# 14     65–69   1,999,287   2,174,064   4,173,351    5.20
# 15     70–74   2,247,196   2,614,043   4,861,239    6.06
# 16     75–79   1,413,881   1,856,402   3,270,283    4.08
# 17     80–84     878,797   1,449,286   2,328,083    2.90
# 18     85–89     369,029     966,047   1,335,076    1.66
# 19     90–94      95,074     335,526     430,600    0.54

# %% [markdown]
# <font color="red" size = "4" face = "small fonts">-------------------------------------------------------------------------------</font></center><br>
#
# <font color="red" size = "4" face = "small fonts">Calificación del siguinte bloque 2/5</font></center><br>

# %% [markdown]
# <center><img src= '..//data/imageProject.png' width='200' height='400'></center>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">1. Integrar los datos de los archivos de Excel y generar un archivo temporal.csv que se almacene en el paquete \data\ Lo anterior se debe generar mediante una función escrita en Python y almacenada en la módulo functions y en un archivo.py, ejemplo /functions/myfunctions.py</font></center><br>
#
# <font color="Orange" size = "4" face = "small fonts">Calificación 0,5 de 2 </font></center><br>

# %%
#Code
every_excel = os.path.join(os.getcwd(),".." ,"data")

print(unir_excel_en_csv(every_excel))

df = pd.read_csv(os.path.join(os.getcwd(), ".." , "data" , "temporal.csv"))
df.head(10)
# Out:
# Todo unido a csv yay jejej
# /tmp/ipykernel_469561/154461055.py:6: DtypeWarning: Columns (0: Mat.gestion.stock) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(os.getcwd(), ".." , "data" , "temporal.csv"))
#   Mat.gestion.stock     Material Texto breve de material  TpMt UMB  Mat  SM  \
# 0       71500041212  91500030918                  FILTER  HERS  ST  NaN NaN
# 1       71500041243  91500025071                   CABLE  HERS   M  NaN NaN
# 2       71500041267  91500025073   TOOTH,SURFACE RIPPING  HERS  ST  NaN NaN
# 3       71500041270  91500025074                 BUSHING  HERS  ST  NaN NaN
# 4       71500041291  91500025075                 BUSHING  HERS  ST  NaN NaN
# 5       71500041309  91500051095                  GASKET  HERS  ST  NaN NaN
# 6       71500041326  91500051219                 BEARING  HERS  ST  NaN NaN
# 7       71500041329  91500051372                 BUSHING  HERS  ST  NaN NaN
# 8       71500041331  91500051275              DISK,VALVE  HERS  ST  NaN NaN
# 9       71500041339  91500032089              O-RING SET  HERS  ST  NaN NaN
#
#    Grupo art.  Jquía.productos          NºFb Fabricante  Grupo artíc. ext.  \
# 0      401615              NaN       3322877   GROVE-CR                NaN
# 1      261216              NaN        550837     BELDEN                NaN
# 2      401728              NaN  ISG728930421   NUOVO-PI                NaN
# 3      311716              NaN  ISG728922441   NUOVO-PI                NaN
# 4      311716              NaN  ISG728922451   NUOVO-PI                NaN
# 5        3118              NaN   3-2500VCS-T    PIKOTEK                NaN
# 6      311715              NaN   PP001HSA-08   IMO-PUMP                NaN
# 7      311716              NaN        109458   UNION-PU                NaN
# 8      401416              NaN        104161   CROSBY-G                NaN
# 9    31401503              NaN      P-52-018      ENDYN                NaN
#
#        Creado    Últ.mod.
# 0  2017-12-06         NaN
# 1  2017-06-23         NaN
# 2  2017-06-23  2022-11-01
# 3  2017-06-23         NaN
# 4  2017-06-23         NaN
# 5  2019-06-14  2022-11-01
# 6  2019-06-15         NaN
# 7  2019-06-15         NaN
# 8  2019-06-15  2022-11-01
# 9  2018-01-19         NaN

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">2. Con el archivo temporal.csv se debe realizar la siguiente transformación, recordar que todo se debe realizar con funciones escritas en un archivo.py guardado en la carpeta \functions e invocadas en archivo parcialBDM.ipynb</font></center><br>
#
# <font color="yellow" size = "4" face = "small fonts">*   Cambiar los encabezados por: stock, material, descripcion, tipoMaterial, umb, mat, sm, grupo, jerarquia, numerofab, fabricante, extension, creado, modificado</font></center><br>
#
# <font color="yellow" size = "4" face = "small fonts">*   Eliminar las columnas que no tengan ningun dato y eliminar todos los registros que no tengan fecha en la columna modificado.</font></center><br>
#
# <font color="Orange" size = "4" face = "small fonts">Calificación 0,5 de 2 </font></center><br>

# %%
#Code
new_columns = ["stock","material","descripcion","tipoMaterial","umb","mat","sm","grupo","jerarquia","numerofab","fabricante","extension","creado","modificado"]
data_path = os.path.join(os.getcwd(), ".." , "data")

df = alterar_columnas(data_path,new_columns)

csv_df = pd.read_csv(os.path.join(os.getcwd(), ".." , "data" , "temporal.csv"))
csv_df.head(10)
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:31: DtypeWarning: Columns (0: Mat.gestion.stock) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(new_data_path)
# /tmp/ipykernel_469561/2967848945.py:7: DtypeWarning: Columns (0: stock) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_df = pd.read_csv(os.path.join(os.getcwd(), ".." , "data" , "temporal.csv"))
#          stock     material            descripcion tipoMaterial umb  mat  \
# 0  71500041267  91500025073  TOOTH,SURFACE RIPPING         HERS  ST  NaN
# 1  71500041309  91500051095                 GASKET         HERS  ST  NaN
# 2  71500041331  91500051275             DISK,VALVE         HERS  ST  NaN
# 3  71500041378  91500031850          RING, WEARING         HERS  ST  NaN
# 4  71500041493  91500009290                 SPRING         HERS  ST  NaN
# 5  71500041509  91500009511                PACKING         HERS  ST  NaN
# 6  71500041544  91500051002                   SEAL         HERS  ST  NaN
# 7  71500041548  91500016389                   SEAL         HERS  ST  NaN
# 8  71500041548  91500035241                   SEAL         HERS  ST  NaN
# 9  71500041549  91500016390                   SEAL         HERS  ST  NaN
#
#       grupo       numerofab fabricante      creado  modificado
# 0    401728    ISG728930421   NUOVO-PI  2017-06-23  2022-11-01
# 1      3118     3-2500VCS-T    PIKOTEK  2019-06-14  2022-11-01
# 2    401416          104161   CROSBY-G  2019-06-15  2022-11-01
# 3  40151725      B32820F004     GOULDS  2017-12-29  2022-10-01
# 4    401515        2L2515CR     FARRIS  2016-11-28  2022-11-01
# 5      3140          507879   MUEL-STE  2019-06-11  2022-11-01
# 6    311817         3690773    IR-COMP  2019-06-14  2022-11-01
# 7    311817      6965005117   ROTOFLOW  2017-02-14  2022-11-01
# 8    311817  GPI-6965005117    GPI-INT  2018-06-05  2022-11-01
# 9    311817      6965084330   ROTOFLOW  2017-02-14  2022-11-01

# %% [markdown]
# <font color="orange" size = "4" face = "small fonts">Tenga en cuenta que las Bases de Datos se encuentran en el contenedor del Docker (Taller anterior)</font></center><br>

# %% [markdown]
# ### Escribir el script en este Markdown de creación e inicio de la BD.
#
# ```docker
# docker run -dit --name tallerbd -p 9090:3306 -e MYSQL_ROOT_PASSWORD=root mysql:latest
# docker exec -it tallerbd mysql -u root -p
#
# ```
#
# ``` SQL
# password:root
# create database parcialDB;
# use parcialDB;
#
# CREATE TABLE IF NOT EXISTS producto(
#     material VARCHAR(255),
#     descripcion VARCHAR(255),
#     fabricante VARCHAR(255),
#     modificado DATE
# );
# ```

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">3. Importar el archivo data.csv a una tabla producto de una Bases de Datos mariaDB. Todas las sentencias se deben realizar desde este cuaderno y con funciones.</font></center><br>
#
# <font color="yellow" size = "4" face = "small fonts">* Crear la Bases de Datos con el nombre parcialDB y una tabla de nombre "producto" con las columnas material, descripcion, fabricante y modificado.</font></center><br>
#
# <font color="yellow" size = "4" face = "small fonts">* Cargar los datos desde temporal.csv a la tabla "material"</font></center><br>
#
#
# <font color="Orange" size = "4" face = "small fonts">Calificación 0,5 de 2 </font></center><br>

# %%
#Code

conn = establecer_conexion(PARCIALDB)
my_csv_path = os.path.join(os.getcwd(), "..", "data","temporal.csv")

query = "INSERT INTO producto (material, descripcion, fabricante, modificado) VALUES (%s, %s, %s, %s)"
columnas = ('material', 'descripcion', 'fabricante', 'modificado')


cargar_datos(conn,my_csv_path,columnas,query)
query = "SELECT * FROM producto"
data_loaded = pd.read_sql(query,conn)

conn.close()
data_loaded.head(10)
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:56: DtypeWarning: Columns (0: stock) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# /tmp/ipykernel_469561/734827896.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_loaded = pd.read_sql(query,conn)
#       material            descripcion fabricante  modificado
# 0  91500025073  TOOTH,SURFACE RIPPING   NUOVO-PI  2022-11-01
# 1  91500051095                 GASKET    PIKOTEK  2022-11-01
# 2  91500051275             DISK,VALVE   CROSBY-G  2022-11-01
# 3  91500031850          RING, WEARING     GOULDS  2022-10-01
# 4  91500009290                 SPRING     FARRIS  2022-11-01
# 5  91500009511                PACKING   MUEL-STE  2022-11-01
# 6  91500051002                   SEAL    IR-COMP  2022-11-01
# 7  91500016389                   SEAL   ROTOFLOW  2022-11-01
# 8  91500035241                   SEAL    GPI-INT  2022-11-01
# 9  91500016390                   SEAL   ROTOFLOW  2022-11-01

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">4. Generar graficas desde los datos contenidos en la base de datos parcialDB, tabla producto. </font></center><br>
# <font color="Orange" size = "4" face = "small fonts">Calificación 0,5 de 2 </font></center><br>

# %%
conn = establecer_conexion(PARCIALDB)
grafica_data = cantidad_por_producto(conn)
conn.close()

if grafica_data is not None:
    top_10 = grafica_data.nlargest(10, 'cantidad')
    plt.figure(figsize=(12,6))
    sns.set_theme(style="whitegrid")

    ax = sns.barplot(x='fabricante', y='cantidad', data=top_10, hue='fabricante',palette='viridis')

    plt.title('Cantidad de Productos por Fabricante', fontsize=15)
    plt.xlabel('Fabricante', fontsize=12)
    plt.ylabel('Total de Productos', fontsize=12)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:76: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)

# %%
conn = establecer_conexion(PARCIALDB)
data_tiempo = obtener_datos_tiempo(conn)

if data_tiempo is not None:
    plt.figure(figsize=(20,6))
    sns.set_theme(style="whitegrid")

    sns.lineplot(x='modificado', y='conteo', data=data_tiempo, 
                 marker='o', markersize=3, 
                 color='red', linewidth=1) 

    sns.lineplot(x='modificado', y='conteo', data=data_tiempo, marker='o', color='red')

    plt.title('Historial de Modificaciones por Fecha', fontsize=15)
    plt.xticks(rotation=45)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:88: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %% [markdown]
# <font color="red" size = "4" face = "small fonts">-------------------------------------------------------------------------------</font></center><br>
#
# <font color="red" size = "4" face = "small fonts">Calificación del siguinte bloque 2/5</font></center><br>

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">1. Crear y cargar la base de datos de recursos humanos dentro del contenedor Docker, recuerde se debe realizar todas las sentencias y programación necesaria desde este cuaderno. </font></center><br>
# <font color="Orange" size = "4" face = "small fonts">Calificación 1 de 2 </font></center><br>

# %% [markdown]
# #### Carga a base de datos

# %%
sql_path = os.path.join(os.getcwd(), "..", "data", "bd_hr.sql")
nombre_bd = "bdrh"
print(crear_nueva_db(sql_path, nombre_bd))

conn = establecer_conexion(nombre_bd)
# Out:
# Not a query: /* Creación de la Base de Dato... -> 1007 (HY000): Can't create database 'bdrh'; database exists
# Not a query:
#
# /* Crear la tabla regiones*/... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla paises*/
# C... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla ubicacione... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla trabajos*/... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla trabajos*/... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla empleados*... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Not a query:
#
# /* Crear la tabla dependient... -> 1681: Integer display width is deprecated and will be removed in a future release.
# Nueva base de datos creada

# %% [markdown]
# ### Comprobar que si hayan datos en las tablas
# ##### Para ello decidimos tomar los 5 primeros registros para ver que en efecto la data si se haya cargado

# %% [markdown]
# #### Tabla: departamentos

# %%
df_departamentos = perform_basic_select(conn,"departamentos")
df_departamentos
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    departamento_id departamento_nombre  ubicacion_id
# 0                1      Administration          1700
# 1                2           Marketing          1800
# 2                3          Purchasing          1700
# 3                4     Human Resources          2400
# 4                5            Shipping          1500

# %% [markdown]
# #### Tabla:dependientes

# %%
df_dependientes = perform_basic_select(conn,"dependientes")
df_dependientes
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    dependiente_id   nombres apellidos vinculo  empleado_id
# 0               1  Penelope     Gietz   Child          206
# 1               2      Nick   Higgins   Child          205
# 2               3        Ed    Whalen   Child          200
# 3               4  Jennifer      King   Child          100
# 4               5    Johnny   Kochhar   Child          101

# %% [markdown]
# #### Tabla: empleados

# %%
df_empleados = perform_basic_select(conn,"empleados")
df_empleados
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    empleado_id    nombres apellidos                             email  \
# 0          100     Steven      King       steven.king@sqltutorial.org
# 1          101      Neena   Kochhar     neena.kochhar@sqltutorial.org
# 2          102        Lex   De Haan       lex.de haan@sqltutorial.org
# 3          103  Alexander    Hunold  alexander.hunold@sqltutorial.org
# 4          104      Bruce     Ernst       bruce.ernst@sqltutorial.org
#
#   numero_telefono fecha_ingreso  trabajo_id  salario  gerencia_id  \
# 0    515.123.4567    1987-06-17           4  24000.0          NaN
# 1    515.123.4568    1989-09-21           5  17000.0        100.0
# 2    515.123.4569    1993-01-13           5  17000.0        100.0
# 3    590.423.4567    1990-01-03           9   9000.0        102.0
# 4    590.423.4568    1991-05-21           9   6000.0        103.0
#
#    departamento_id
# 0                9
# 1                9
# 2                9
# 3                6
# 4                6

# %% [markdown]
# #### Tabla: paises

# %%
df_paises = perform_basic_select(conn,"paises") 
df_paises
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#   pais_id pais_nombre  region_id
# 0      AR   Argentina          2
# 1      AU   Australia          3
# 2      BE     Belgium          1
# 3      BR      Brazil          2
# 4      CA      Canada          2

# %% [markdown]
# #### Tabla: regiones

# %%
df_regiones = perform_basic_select(conn,"regiones")
df_regiones
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    region_id         region_nombre
# 0          1                Europa
# 1          2              Américas
# 2          3         Asia-Pacífico
# 3          4  Oriente Medio/África

# %% [markdown]
# #### Tabla: trabajos

# %%
df_trabajos = perform_basic_select(conn,"trabajos")
df_trabajos
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    trabajo_id                 trabajo_nombre  salario_min  salario_max
# 0           1              Public Accountant       4200.0       9000.0
# 1           2             Accounting Manager       8200.0      16000.0
# 2           3       Administration Assistant       3000.0       6000.0
# 3           4                      President      20000.0      40000.0
# 4           5  Administration Vice President      15000.0      30000.0

# %% [markdown]
# #### Tabla: ubicaciones

# %%
df_ubicaciones = perform_basic_select(conn,"ubicaciones")
df_ubicaciones
# Out:
# /home/juancho/Documents/pandas_stuff/TallerPythonPandas/functions/misfunciones.py:128: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(f"SELECT * FROM {table} LIMIT 5",conn)
#    ubicacion_id            direccion codigo_postal               ciudad  \
# 0          1400  2014 Jabberwocky Rd         26192            Southlake
# 1          1500  2011 Interiors Blvd         99236  South San Francisco
# 2          1700      2004 Charade Rd         98199              Seattle
# 3          1800      147 Spadina Ave       M5V 2L7              Toronto
# 4          2400       8204 Arthur St           NaN               London
#
#   estado_provincia pais_id
# 0            Texas      US
# 1       California      US
# 2       Washington      US
# 3          Ontario      CA
# 4              NaN      UK

# %%
conn.close()

# %% [markdown]
# <font color="yellow" size = "4" face = "small fonts">2. Generar la siguinte consulta de la base de datos - recursos humanos.  </font></center><br>
# <font color="yellow" size = "4" face = "small fonts">- -Se desea conocer los empleados cuyo salario es superior al salario promedio de todos los empleados. </font></center><br>
# <font color="Orange" size = "4" face = "small fonts">Calificación 0,5 de 2 </font></center><br>

# %%
conn = establecer_conexion(BDRH)

query = """
    SELECT empleado_id, nombres,apellidos 
    FROM empleados 
    WHERE salario > (SELECT AVG(salario) from empleados);

"""


df = pd.read_sql(query,conn)
df
# Out:
# /tmp/ipykernel_469561/1182959438.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)
#     empleado_id    nombres   apellidos
# 0           100     Steven        King
# 1           101      Neena     Kochhar
# 2           102        Lex     De Haan
# 3           103  Alexander      Hunold
# 4           108      Nancy   Greenberg
# 5           109     Daniel      Faviet
# 6           110       John        Chen
# 7           114        Den    Raphaely
# 8           121       Adam       Fripp
# 9           145       John     Russell
# 10          146      Karen    Partners
# 11          176   Jonathon      Taylor
# 12          177       Jack  Livingston
# 13          201    Michael   Hartstein
# 14          204    Hermann        Baer
# 15          205    Shelley     Higgins
# 16          206    William       Gietz

# %% [markdown]
# <center><font color="red" size = "4" face = "small fonts">CUANDO TERMINE EL PRÁCTICO CREE UN ARCHIVO.ZIP DE LA CARPETA DEL PROYECTO Y CÁRGUELO AL AULA VIRTUAL.</font></center>
