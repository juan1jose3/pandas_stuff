# %%
import os

# %% [markdown]
# Con un archivo .agp de debe poder hacer lo siguiente: Crear, Abrir ,Editar, eliminar

# %% [markdown]
# Crear y abrir

# %%
# Out:
# dkjfhdj

# %%
import os

with open('data.agp', 'w') as fp:
    pass

with open("data.agp", "a", encoding="utf-8") as f:
    f.write("Sofía.\n")
    f.write("Martina.\n")
    f.write("Daniela.\n")
    f.write("Valeria.\n")
    f.write("Mateo.\n")

# %% [markdown]
# editar

# %%
with open("data.agp", "a", encoding="utf-8") as f:
    f.write("Lucas.\n")
    f.write("Martín.\n")
    f.write("Pedro.\n")

# %% [markdown]
# Buscar

# %%
personas =[] 
persona = "Pedro"
with open("data.agp", "r", encoding="utf-8") as f:
    personas.append(f.read())


for i in personas:
   if "\n"+persona:
       print(persona)
# Out:
# Pedro

# %% [markdown]
# eliminar

# %%
import os
os.remove("data.agp")
